# %%
class Array:
    def __init__(self , tam ):
        self.__tamanio = tam
        self.__data = [ 0 for x in range(self.__tamanio) ]

    def to_string( self ):
        info = ""
        for dato in self.__data:
            info = info + str(dato) +"|"
        return info

    def get_item ( self , index ):
        return self.__data[index]
    
    def get_length( self ):
        return len( self.__data)
    
    def set_item( self , dato , index):
        #hace falta revisar limites
        if index >= 0 and index < self.get_length():
            self.__data[index] = dato
        else:
            print("Error: indice fuera de rango")
    

    def clear ( self , dato ):
        self.__data = [ dato for x in range(self.__tamanio) ]

ejemplo = Array(20)
print( ejemplo.to_string() )
print( ejemplo.get_item(2) )
ejemplo.set_item( 45 , 2 )
print(ejemplo.to_string() )
#ejemplo.clear( 4 )
print( ejemplo.to_string() )
print(ejemplo.get_lengh())

# %%
lista=[3*x for x in range(5)]
print(lista)

# %% [markdown]
# 7/10/21

# %%
# !cat junio.dat
# Out:
# cat: junio.dat: No such file or directory

# %%
archivo=open('junio.dat', 'rt', encoding='latin-1')
print(archivo.read())

# %%
class Trabajador:
  def init__(self, nt, nom, pat, mat, he, sb, ai):
    #asi para todos los atributos
    
    #aqui van todos los metodos de acceso
   def set_numero_trabajador(self, nt):
       self.__numero_trabajador=not

  #metodos que hacen calculos de la logica de negocio
# Out:
#   File "<ipython-input-20-eeaf4f4aa29d>", line 7
#     self.__numero_trabajador=not
#                                 ^
# SyntaxError: invalid syntax

# %%
class NominaDT: 
  def __init(self, ruta_archivo):
    #abrir el archivo, y determinar el numero de empleados--->num_emp
    self.__data=Array(num_emp)
    def calcular_sueldos(self):
      #va a iterar sobr Array y hacer calculos e sueldos
      def buscar_mas_antiguo(self):
        #va a iterar y buscara en el Array y el d mayor antiguedad en el puesto
        def buscar_menor_antiguedad(self):
          #lo mismo de arriba pero para el menor
# Out:
#   File "<ipython-input-17-ac1396b1cbec>", line 10
#     #lo mismo de arriba pero para el menor
#                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
sueldo_base=100
anio=2019
anti=2
prestacion=100*(2*0.03)
print(sueldo_base + prestacion)
